# %%
from lazypredict.Supervised import LazyRegressor
import pandas as pd
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import *
from sklearn.model_selection import cross_val_score, cross_validate, GridSearchCV, KFold, RandomizedSearchCV, train_test_split
import matplotlib.pyplot as plt
import shap

# %%
data = pd.read_csv("data_model_trim_logs.csv")

y = data.Ncasos_lead
X = data.drop(["Ncasos_lead", "Mun"], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state =123)

# %%
lazy_reg = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric = None)

models, predictions = lazy_reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 42/42 [09:56<00:00, 14.21s/it]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                                0.81       0.81  0.65        0.13
# HistGradientBoostingRegressor                0.81       0.81  0.65        0.26
# ExtraTreesRegressor                          0.80       0.80  0.66        0.53
# XGBRegressor                                 0.80       0.80  0.67        0.30
# RandomForestRegressor                        0.79       0.79  0.68        1.13
# BaggingRegressor                             0.78       0.78  0.70        0.11
# MLPRegressor                                 0.75       0.75  0.74        1.99
# GradientBoostingRegressor                    0.74       0.74  0.76        0.44
# SVR                                          0.73       0.73  0.77        0.51
# NuSVR                                        0.73       0.73  0.77        0.40
# KNeighborsRegressor                          0.72       0.72  0.78        0.06
# OrthogonalMatchingPursuitCV                  0.65       0.65  0.88        0.01
# HuberRegressor                               0.65       0.65  0.88        0.03
# Lars                                         0.65       0.65  0.88        0.01
# LarsCV                                       0.65       0.65  0.88        0.02
# LassoLarsIC                                  0.65       0.65  0.88        0.02
# LinearRegression                             0.65       0.65  0.88        0.01
# TransformedTargetRegressor                   0.65       0.65  0.88        0.01
# RidgeCV                                      0.65       0.65  0.88        0.04
# LinearSVR                                    0.65       0.65  0.88        0.11
# Ridge                                        0.65       0.65  0.88        0.01
# BayesianRidge                                0.65       0.65  0.88        0.02
# LassoLarsCV                                  0.65       0.65  0.88        0.05
# LassoCV                                      0.65       0.65  0.88        0.15
# ElasticNetCV                                 0.65       0.65  0.88        0.12
# SGDRegressor                                 0.64       0.65  0.89        0.01
# OrthogonalMatchingPursuit                    0.61       0.61  0.93        0.01
# AdaBoostRegressor                            0.60       0.60  0.94        0.10
# PoissonRegressor                             0.58       0.59  0.96        0.61
# DecisionTreeRegressor                        0.58       0.58  0.97        0.03
# TweedieRegressor                             0.54       0.55  1.00        0.57
# ExtraTreeRegressor                           0.54       0.54  1.01        0.03
# ElasticNet                                   0.39       0.40  1.15        0.04
# Lasso                                        0.16       0.16  1.36        0.04
# DummyRegressor                              -0.01      -0.00  1.49        0.01
# LassoLars                                   -0.01      -0.00  1.49        0.02
# QuantileRegressor                           -0.02      -0.01  1.50      587.19
# RANSACRegressor                             -0.22      -0.21  1.64        0.21
# PassiveAggressiveRegressor                  -0.48      -0.47  1.80        0.01
# KernelRidge                                 -6.88      -6.83  4.16        0.58
# GaussianProcessRegressor                   -61.60     -61.19 11.74        1.05

# %%
df_models
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE
# Model
# LGBMRegressor                                0.81       0.81  0.65
# HistGradientBoostingRegressor                0.81       0.81  0.65
# ExtraTreesRegressor                          0.80       0.80  0.66
# XGBRegressor                                 0.80       0.80  0.67
# RandomForestRegressor                        0.79       0.79  0.68
# BaggingRegressor                             0.78       0.78  0.70
# MLPRegressor                                 0.75       0.75  0.74
# GradientBoostingRegressor                    0.74       0.74  0.76
# SVR                                          0.73       0.73  0.77
# NuSVR                                        0.73       0.73  0.77
# KNeighborsRegressor                          0.72       0.72  0.78
# OrthogonalMatchingPursuitCV                  0.65       0.65  0.88
# HuberRegressor                               0.65       0.65  0.88
# Lars                                         0.65       0.65  0.88
# LarsCV                                       0.65       0.65  0.88
# LassoLarsIC                                  0.65       0.65  0.88
# LinearRegression                             0.65       0.65  0.88
# TransformedTargetRegressor                   0.65       0.65  0.88
# RidgeCV                                      0.65       0.65  0.88
# LinearSVR                                    0.65       0.65  0.88
# Ridge                                        0.65       0.65  0.88
# BayesianRidge                                0.65       0.65  0.88
# LassoLarsCV                                  0.65       0.65  0.88
# LassoCV                                      0.65       0.65  0.88
# ElasticNetCV                                 0.65       0.65  0.88
# SGDRegressor                                 0.64       0.65  0.89
# OrthogonalMatchingPursuit                    0.61       0.61  0.93
# AdaBoostRegressor                            0.60       0.60  0.94
# PoissonRegressor                             0.58       0.59  0.96
# DecisionTreeRegressor                        0.58       0.58  0.97
# TweedieRegressor                             0.54       0.55  1.00
# ExtraTreeRegressor                           0.54       0.54  1.01
# ElasticNet                                   0.39       0.40  1.15
# Lasso                                        0.16       0.16  1.36
# DummyRegressor                              -0.01      -0.00  1.49
# LassoLars                                   -0.01      -0.00  1.49
# QuantileRegressor                           -0.02      -0.01  1.50
# RANSACRegressor                             -0.22      -0.21  1.64
# PassiveAggressiveRegressor                  -0.48      -0.47  1.80
# KernelRidge                                 -6.88      -6.83  4.16
# GaussianProcessRegressor                   -61.60     -61.19 11.74
